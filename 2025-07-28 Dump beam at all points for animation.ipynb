# %%
from UTILITY_quickstart import *
importedDefaultSettings = loadConfig("setLattice_configs/2024-10-14_twoBunch_baseline.yml")

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"],
    
    csrTF = True,
    numMacroParticles=1e5,
    scratchPath = "/tmp",
    randomizeFileNames = True
)

setLattice(tao, **importedDefaultSettings )
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-S2E
# CSR on
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using /Users/nmajik/Documents/SLAC/FACET2-S2E/setLattice_configs/defaults.yml
# Number of macro particles = 100000.0
# Beam created, written to /tmp/beams/activeBeamFile_4324560604544060241.h5, and reinit to tao

# %%
#Use dump_file
tao.cmd('set beam dump_file = "tao_dump.h5"')
#tao.cmd('set beam dump_at = "E*D*"')
tao.cmd('set beam dump_at = "*"')
# Out:
# []

# %%
trackBeam(tao, 
          **importedDefaultSettings,
          verbose = True
         )
# Out:
# Loaded /tmp/beams/activeBeamFile_4324560604544060241.h5
# Set track_start = L0AFEND, track_end = end
# Tracking!
# trackBeam() exiting

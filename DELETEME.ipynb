# %%
from UTILITY_quickstart import *

# %%
tao = initializeTao()
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-S2E
# CSR off
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using /Users/nmajik/Documents/SLAC/FACET2-S2E/setLattice_configs/defaults.yml
# WARNING! No beam file is specified!
# Number of macro particles defined by input file
# Beam created, written to /Users/nmajik/Documents/SLAC/FACET2-S2E/beams/activeBeamFile.h5, and reinit to tao

# %%
tao.cmd('show lat SBEND::* -att FRINGE_TYPE ')
# Out:
# ['# Values shown are for the Downstream End of each Element (Girder elements shown at ref point):',
#  '# Index  name     key                      s       l  FRINGE_TYPE',
#  '     79  BCX10451 SBend                8.759   0.125  Full',
#  '     81  BCX10461 SBend                9.026   0.125  Full',
#  '     91  BCX10475 SBend                9.981   0.125  Full',
#  '     93  BCX10481 SBend               10.248   0.125  Full',
#  '    144  BX10661  SBend               16.954   0.204  Full',
#  '    155  BX10751  SBend               18.718   0.204  Full',
#  '    232  BCX11314 SBend               40.616   0.204  Full',
#  '    240  BCX11331 SBend               43.265   0.204  Full',
#  '    248  BCX11338 SBend               44.299   0.204  Full',
#  '    258  BCX11355 SBend               46.948   0.204  Full',
#  '    686  BCX14720 SBend              398.817   0.549  Full',
#  '    692  BCX14796 SBend              409.237   0.549  Full',
#  '    698  BCX14808 SBend              410.879   0.549  Full',
#  '    704  BCX14883 SBend              421.299   0.549  Full',
#  '   1296  B1LE     SBend              930.600   1.063  Full',
#  '   1323  B2LE#1   SBend              940.864   0.912  Full',
#  '   1325  B2LE#2   SBend              941.776   0.912  Full',
#  '   1372  B3LE#1   SBend              953.418   0.264  Full',
#  '   1374  B3LE#2   SBend              953.682   0.264  Full',
#  '   1383  B3RE#1   SBend              954.740   0.264  Full',
#  '   1385  B3RE#2   SBend              955.005   0.264  Full',
#  '   1433  B2RE#1   SBend              967.294   0.912  Full',
#  '   1435  B2RE#2   SBend              968.207   0.912  Full',
#  '   1445  WIGE1    SBend              970.533   0.244  Full',
#  '   1447  WIGE2#1  SBend              970.904   0.244  Full',
#  '   1449  WIGE2#2  SBend              971.148   0.244  Full',
#  '   1451  WIGE3    SBend              971.518   0.244  Full',
#  '   1463  B1RE     SBend              978.621   1.063  Full',
#  '   1570  B5D36    SBend             1007.332   0.978  Full',
#  'Lord Elements:',
#  '   1760  B2LE     SBend              941.776   1.825  Full',
#  '   1761  B3LE     SBend              953.682   0.529  Full',
#  '   1762  B3RE     SBend              955.005   0.529  Full',
#  '   1763  B2RE     SBend              968.207   1.825  Full',
#  '   1764  WIGE2    SBend              971.148   0.488  Full',
#  '# Index  name     key                      s       l  FRINGE_TYPE',
#  '# Values shown are for the Downstream End of each Element (Girder elements shown at ref point):']

# %%
floorplanPlot(
    tao,
    zmin = 0,
    zmax = 15 #11.535
)

# %%
importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_baseline3.yml")

setLattice(tao, **importedDefaultSettings)

# %%
launchTwissCorrection(tao)
# Out:
# No evalElement provided. Assuming golden lattice PR10571
# Optimization Results:
# Optimal Parameters: [35.03550563 16.56305755 24.6586748  17.62176522]
# Objective Function Value at Optimal Parameters: 2.0959764005380888e-11
# Number of Iterations: 390
# Converged: True

# %%
floorplanPlot(
    tao,
    zmin = 0,
    zmax = 15 #11.535
)

# %%
importedDefaultSettings
# Out:
# {'QA10361kG': -3.1976079537,
#  'QA10371kG': 3.1129092742,
#  'QE10425kG': -6.8469996218,
#  'QE10441kG': 1.5057761462,
#  'QE10511kG': 7.0138622173,
#  'QE10525kG': -5.3942250594,
#  'Q19851kG': -64.095,
#  'Q19871kG': 44.936,
#  'B1EkG': 7.533,
#  'B2EkG': -10.942,
#  'B3EkG': 3.409,
#  'Q1EkG': 161.311,
#  'Q2EkG': -154.229,
#  'Q3EkG': 110.217,
#  'Q4EkG': 132.268,
#  'Q5EkG': -23.373,
#  'Q6EkG': -142.271,
#  'symmetricSextupoleStrengths': True,
#  'S1ELkG': 9.5354261372,
#  'S2ELkG': -998.8857534325,
#  'S3ELkG': -312.4574420756,
#  'S3ERkG': -1019.323,
#  'S2ERkG': -2049.489,
#  'S1ERkG': 804.871,
#  'Q5FFkG': -71.837,
#  'Q4FFkG': -81.251,
#  'Q3FFkG': 99.225,
#  'Q2FFkG': 126.35,
#  'Q1FFkG': -235.218,
#  'Q0FFkG': 126.353,
#  'Q0DkG': -109.694,
#  'Q1DkG': 180.862,
#  'Q2DkG': -109.694,
#  'S1EL_xOffset': -0.0024831962,
#  'S1EL_yOffset': 0.0024286168,
#  'S2EL_xOffset': 0.0003279967,
#  'S2EL_yOffset': -0.0001951917,
#  'S2ER_xOffset': 0.0025878477,
#  'S2ER_yOffset': -2.64729e-05,
#  'S1ER_xOffset': 0.0021476773,
#  'S1ER_yOffset': -0.0003583632,
#  'XC1FFkG': 0.0,
#  'XC3FFkG': 0.0,
#  'YC1FFkG': 0.0,
#  'YC2FFkG': 0.0,
#  'B5D36GeVc': 10.0,
#  'L0BPhaseSet': -15.0,
#  'L1PhaseSet': -28.9100908383,
#  'L2PhaseSet': -39.0717691285,
#  'L3PhaseSet': 0,
#  'L0BEnergyOffset': -2759313,
#  'L1EnergyOffset': 0,
#  'L2EnergyOffset': 0,
#  'L3EnergyOffset': 0,
#  'XTCAVvoltage': 0,
#  'XTCAVphase': 0,
#  'QA10361kGBounds': '(-10.1, 10.2)',
#  'QA10371kGBounds': '(-10.1, 10.1)',
#  'QE10425kGBounds': '(-10.1, 10.1)',
#  'QE10441kGBounds': '(-10.1, 10.1)',
#  'QE10511kGBounds': '(-10.1, 10.1)',
#  'QE10525kGBounds': '(-10.1, 10.1)',
#  'Q19851kGBounds': '(-101, 0)',
#  'Q19871kGBounds': '(0, 101)',
#  'B1EkGBounds': '(0, 18.83)',
#  'B2EkGBounds': '(-27.4, 0)',
#  'B3EkGBounds': '(0, 8.5)',
#  'Q1EkGBounds': '(0, 388)',
#  'Q2EkGBounds': '(-364, 0)',
#  'Q3EkGBounds': '(0, 299)',
#  'Q4EkGBounds': '(0, 304)',
#  'Q5EkGBounds': '(-117, 0)',
#  'Q6EkGBounds': '(-301, 0)',
#  'Q1ELBoostkGBounds': '(0, 56)',
#  'Q2ELBoostkGBounds': '(-36, 0)',
#  'Q3ELBoostkGBounds': '(0, 32.4)',
#  'Q4ELBoostkGBounds': '(0, 27.4)',
#  'Q5ELBoostkGBounds': '(-12.4, 0)',
#  'Q5ERBoostkGBounds': '(-12.4, 0)',
#  'Q4ERBoostkGBounds': '(0, 27.6)',
#  'Q3ERBoostkGBounds': '(0, 32.4)',
#  'Q2ERBoostkGBounds': '(-35.9, 0)',
#  'Q1ERBoostkGBounds': '(0, 55.6)',
#  'S1ELkGBounds': '(0,2590)',
#  'S2ELkGBounds': '(-21706,0)',
#  'S3ELkGBounds': '(-2625,0)',
#  'S3ERkGBounds': '(-2603,0)',
#  'S2ERkGBounds': '(-21638,0)',
#  'S1ERkGBounds': '(0,2601)',
#  'Q5FFkGBounds': '(-256, 0)',
#  'Q4FFkGBounds': '(-446, 0)',
#  'Q3FFkGBounds': '(0, 457)',
#  'Q2FFkGBounds': '(0, 167)',
#  'Q1FFkGBounds': '(-257, 0)',
#  'Q0FFkGBounds': '(0, 167)',
#  'Q0DkGBounds': '(-239, 0)',
#  'Q1DkGBounds': '(0, 386)',
#  'Q2DkGBounds': '(-223, 0)',
#  'XC1FFkGBounds': '(-0.37, 0.37)',
#  'XC3FFkGBounds': '(-0.37, 0.37)',
#  'YC1FFkGBounds': '(-0.37, 0.37)',
#  'YC2FFkGBounds': '(-0.38, 0.38)',
#  'inputBeamFilePathSuffix': '/beams/2024-10-22_Impact_OneBunch/2024-10-22_oneBunch.h5',
#  'bunchCount': 1,
#  'centerBC14': True,
#  'centerBC20': True,
#  'centerMFFF': True,
#  'assertBC14Energy': True,
#  'assertBC20Energy': True}

# %% [markdown]
# # Initialization

# %%
#Import all the UTILITY functions
from UTILITY_quickstart import *

#Look at the signature and documentation for initializeTao()
# ?initializeTao
# Out:
# Signature:
# initializeTao(
#     filePath=None,
#     runSetLatticeTF=True,
#     setLatticeDefaultsFile=None,
#     numMacroParticles=None,
#     runImpactTF=False,
#     inputBeamFilePathSuffix=None,
#     scratchPath=None,
#     randomizeFileNames=False,
#     csrTF=False,
#     transverseWakes=False,
#     **kwargs,
# )
# Docstring:
# Initialize a Tao object
#
# Parameters
# ----------
# filePath : str, optional
#     Path to the FACET-II lattice files. Defaults to the current working directory.
#
# runSetLatticeTF : bool
#     Whether or not to run setLattice(). If False, the unmodified lattice specified by tao.init is loaded
# setLatticeDefaultsFile : str
#     Path to the file which setLattice() loads. If not specified uses defaults.yml
#
# numMacroparticles : int
#     The number of macroparticles to simulate
# runImpactTF : bool
#     Whether or not to run IMPACT-T to generate an initial beam
# inputBeamFilePathSuffix : str
#     Relative path from filePath to a file containing an intial beam
#
# scratchPath : str
#     Path to write scratch files. If used, typically set to "/tmp"
# randomizeFileNames : bool
#     Add random hashes to file names. Allows for parallel operation
#
# csrTF : bool
#     Enable or disable coherent synchrotron radiation (CSR) in bends
# transverseWakes : bool
#     Enable or disable transverse wakefields within linac sections
#
# Returns
# -------
# Tao
#     Configured Tao object ready for beam tracking.
# File:      ~/Documents/SLAC/FACET2-S2E/UTILITY_quickstart.py
# Type:      function

# %%
#Initialize tao object for single-particle tracking only
tao = initializeTao()
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-S2E
# CSR off
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using /Users/nmajik/Documents/SLAC/FACET2-S2E/setLattice_configs/defaults.yml
# WARNING! No beam file is specified!
# Number of macro particles defined by input file
# Beam created, written to /Users/nmajik/Documents/SLAC/FACET2-S2E/beams/activeBeamFile.h5, and reinit to tao

# %% [markdown]
# # Single-particle results

# %%
# Ensure that the lattice matches the design at standard treaty point, PR10571
launchTwissCorrection(tao)
# Out:
# No evalElement provided. Assuming golden lattice PR10571
# Optimization Results:
# Optimal Parameters: [0.13755483 0.95354498 0.40561992 2.20428422]
# Objective Function Value at Optimal Parameters: 1.5713461387770165e-09
# Number of Iterations: 93
# Converged: True

# %%
# Plot the beta functions and dispersion throughout the whole linac
# Also shows a schematic view of the accelerator
floorplanPlot(tao)

# %%
# Get the Twiss parameters at a particular element
tao.ele_twiss("PENT")
# Out:
# {'mode_flip': False,
#  'beta_a': 0.499382808054094,
#  'alpha_a': 0.0310420410146822,
#  'gamma_a': 2.00440141744313,
#  'phi_a': 73.0934669708683,
#  'eta_a': -5.54002627203796e-06,
#  'etap_a': -1.05997356796689e-05,
#  'beta_b': 0.500632473929507,
#  'alpha_b': -0.0164048278497085,
#  'gamma_b': 1.99801085719746,
#  'phi_b': 60.4949499141395,
#  'eta_b': -2.11805920050045e-18,
#  'etap_b': -2.52222176160021e-18,
#  'eta_x': -5.54002627203796e-06,
#  'etap_x': -1.05997356796689e-05,
#  'eta_y': -2.11784425998279e-18,
#  'etap_y': -2.52067060637746e-18}

# %%
# Calculate a transport matrix between elements
getMatrix(tao, "PENT", "DTOTR", print = True);
# Out:
# <style type="text/css">
# </style>
# <table id="T_481fa">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_481fa_row0_col0" class="data row0 col0" >-3.924442</td>
#       <td id="T_481fa_row0_col1" class="data row0 col1" >-2.027473</td>
#       <td id="T_481fa_row0_col2" class="data row0 col2" >-0.000000</td>
#       <td id="T_481fa_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_481fa_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_481fa_row0_col5" class="data row0 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_481fa_row1_col0" class="data row1 col0" >-0.326665</td>
#       <td id="T_481fa_row1_col1" class="data row1 col1" >-0.423577</td>
#       <td id="T_481fa_row1_col2" class="data row1 col2" >-0.000000</td>
#       <td id="T_481fa_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_481fa_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_481fa_row1_col5" class="data row1 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_481fa_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_481fa_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_481fa_row2_col2" class="data row2 col2" >-1.854894</td>
#       <td id="T_481fa_row2_col3" class="data row2 col3" >1.930395</td>
#       <td id="T_481fa_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_481fa_row2_col5" class="data row2 col5" >0.055920</td>
#     </tr>
#     <tr>
#       <td id="T_481fa_row3_col0" class="data row3 col0" >-0.000000</td>
#       <td id="T_481fa_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_481fa_row3_col2" class="data row3 col2" >-0.136005</td>
#       <td id="T_481fa_row3_col3" class="data row3 col3" >-0.397574</td>
#       <td id="T_481fa_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_481fa_row3_col5" class="data row3 col5" >0.006000</td>
#     </tr>
#     <tr>
#       <td id="T_481fa_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_481fa_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_481fa_row4_col2" class="data row4 col2" >0.003524</td>
#       <td id="T_481fa_row4_col3" class="data row4 col3" >-0.033815</td>
#       <td id="T_481fa_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_481fa_row4_col5" class="data row4 col5" >-0.000006</td>
#     </tr>
#     <tr>
#       <td id="T_481fa_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_481fa_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_481fa_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_481fa_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_481fa_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_481fa_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Multi-particle tracking

# %%
#Load a reference configuration
importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_baseline3.yml")


#Initialize tao object
tao = initializeTao(
    inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"],
    numMacroParticles = 1e4,
    csrTF = False 
        # CSR is usually enabled since it can significantly impact the beam 
        # It's computationally expensive to calculate though
        # Turned off here just to make the demo notebook faster
)

#Set lattice to the loaded config
setLattice(tao, **importedDefaultSettings)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-S2E
# CSR off
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using /Users/nmajik/Documents/SLAC/FACET2-S2E/setLattice_configs/defaults.yml
# Number of macro particles = 10000.0
# Beam created, written to /Users/nmajik/Documents/SLAC/FACET2-S2E/beams/activeBeamFile.h5, and reinit to tao

# %%
#Track the beam from start to end
trackBeam(tao, **importedDefaultSettings)

# %%
#Get the beam at element "PENT"
P =  getBeamAtElement(tao, "PENT")

#Plot the x-y projection of the beam at that location
display(plotMod(P, 'x', 'y',  bins=200));
plt.clf()

print(P)
# Out:
# ParticleGroup with 9998 particles with total charge 1.5996800000000008e-09 C

# %%
#Plot the longitudinal phase space
display(plotMod(P, 'z', 'pz',  bins=200));

# %%
# Evaluate the beam, calculating a variety of useful metrics
getBeamSpecs(P, targetTwiss = "PENT")
# Out:
# {'PDrive_median_x': np.float64(1.2610569774740147e-06),
#  'PDrive_median_y': np.float64(-5.61278296496686e-07),
#  'PDrive_median_xp': np.float64(5.006019359053014e-07),
#  'PDrive_median_yp': np.float64(-1.659219609141242e-08),
#  'PDrive_median_energy': np.float64(9999960899.848206),
#  'PDrive_sigmaSI90_x': np.float64(4.5224743386646165e-05),
#  'PDrive_sigmaSI90_y': np.float64(8.171877337104328e-06),
#  'PDrive_sigmaSI90_z': np.float64(1.4950940789895148e-05),
#  'PDrive_sigmaSI90_xp': np.float64(5.5025335547887784e-05),
#  'PDrive_sigmaSI90_yp': np.float64(1.866836382877083e-05),
#  'PDrive_sigmaSI90_energy': np.float64(24882132.57147053),
#  'PDrive_emitSI90_x': np.float64(2.2304221733821088e-05),
#  'PDrive_emitSI90_y': np.float64(2.9093717371217516e-06),
#  'PDrive_norm_emit_x': np.float64(4.1497107640648005e-06),
#  'PDrive_norm_emit_y': np.float64(1.7305789148698418e-06),
#  'PDrive_charge_nC': np.float64(1.5996800000000009),
#  'PDrive_BMAG_x': np.float64(1.331407127006908),
#  'PDrive_BMAG_y': np.float64(1.2882821291790074),
#  'PDrive_sliced_BMAG_x': [np.float64(5.971780232980742),
#   np.float64(1.7343280375193781),
#   np.float64(1.1381174735560626),
#   np.float64(1.1100707365758349),
#   np.float64(1.8676594392683492)],
#  'PDrive_sliced_BMAG_y': [np.float64(1.6347837465587984),
#   np.float64(1.559156584391507),
#   np.float64(1.4652717181145731),
#   np.float64(1.1911032904802985),
#   np.float64(1.0981493531910604)]}

# %%
# Look at the L2 phase in the present configuration
importedDefaultSettings["L2PhaseSet"]
# Out:
# -39.0717691285

# %%
#Change the phase of L2 to -30 degrees, then update the gradient to maintain same energy gain
setLinacPhase(tao, "L2", -30)
setLinacGradientAuto(tao, "L2", 4.165e9) #Nominal L1 exit energy is 335 MeV and nominal L2 exit energy is 4.5 GeV, hence 4.165 GeV gain here

#Retrack the beam
trackBeam(tao, **importedDefaultSettings)

#Plot the new longitudinal phase space
P =  getBeamAtElement(tao, "PENT")
display(plotMod(P, 'z', 'pz',  bins=200));

# %% [markdown]
# ## Demonstrating partial tracking

# %%
# Sometimes it's only necessary to track a subset of the beamline
# We'll grab the beam from the last simulation at MFFF then make it the "activeBeamFile"
trackStart = "MFFF"
P = getBeamAtElement(tao, trackStart)
makeBeamActiveBeamFile( P, tao = tao ) 

#Then, it is possible to track from that element
trackBeam(
    tao,
    trackStart = trackStart,
    trackEnd = "DTOTR",
    **importedDefaultSettings 
)

# %%
# Check the spot at PENT (which is between trackStart and trackEnd)
P = getBeamAtElement(tao, "PENT")
display(plotMod(P, 'x', 'y',  bins=200));

# %%
#Look at the strength of a final focus quad, Q4FF
#getQuadkG() will return the integrated gradient in kG; these are the same units used by the control system
getQuadkG(tao, "Q4FF")
# Out:
# -81.25125099285313

# %%
#Change that quad setting to -40 kG
setQuadkG(tao, "Q0FF", -40.0)

#Track the beam through a subset of the now-modified lattice
trackBeam(
    tao,
    trackStart = trackStart,
    trackEnd = "DTOTR",
    **importedDefaultSettings 
)

# %%
# Look at the new profile
P = getBeamAtElement(tao, "PENT")
display(plotMod(P, 'x', 'y',  bins=200));

# %% [markdown]
# ## Laser heater
#
# For this section, we'll look at the beam LPS at the exit of the laser heater. We'll compare the beam with the heater off to a Gaussian and arbitrary laser time profile

# %%
#Make a new Tao object with many more particles
tao = initializeTao(
    inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"],
    
    numMacroParticles=1e5,
    scratchPath = "/tmp",
    randomizeFileNames = True
)

setLattice(tao, **importedDefaultSettings)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-S2E
# CSR off
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using /Users/nmajik/Documents/SLAC/FACET2-S2E/setLattice_configs/defaults.yml
# Number of macro particles = 100000.0
# Beam created, written to /tmp/beams/activeBeamFile_7789740760401990988.h5, and reinit to tao

# %% [markdown]
# ### Heater off

# %%
trackBeam(
    tao, 
    trackEnd = "LH10END", 
    **importedDefaultSettings
)

P = getBeamAtElement(tao, "LH10END")

display(plotMod(P, 'delta_t', 'energy', bins=300) )
plt.clf()

# %% [markdown]
# ### Gaussian profile

# %%
laserHeater = {
    "Elaser" : 0.1e-3,
    "case" : "Gaussian",
    "sigmat_laser" : 0.5e-12,
    "offset" : -1e-12
}

trackBeam(
    tao, 
    trackEnd = "LH10END", 
    laserHeater = laserHeater,
    **importedDefaultSettings
)

P = getBeamAtElement(tao, "LH10END")

display(plotMod(P, 'delta_t', 'energy', bins=300) )
plt.clf()

# %% [markdown]
# ### Arbitrary profile

# %%
# Define an arbitrary laser power profile - e.g. sum of 2 Gaussians with different sigmas and offsets

Elaser = 0.01e-3; #Total laser energy in joules

#Time grid on which to calculate the profile
tvector = np.linspace(-15e-12,15e-12,10000);

#Specific settings for this particular example; summed Gaussians
sigmat_laser1 = 0.1e-12;
sigmat_laser2 = 1.5e-12;
offset1 = -1e-12;
offset2 = 2e-12;
amp1 = 1.5;
amp2 = 1;
Pvector = amp1*np.exp(-0.5*((tvector - offset1) / sigmat_laser1)**2) +  amp2*np.exp(-0.5*((tvector - offset2) / sigmat_laser2)**2)


total_energy = np.abs(np.trapezoid(tvector,Pvector)) 
Pvector = Pvector*(Elaser/total_energy)# Normalize to the total laser energy

#print(np.abs(np.trapezoid(tvector,Pvector)))
plt.plot(tvector*1e12,Pvector); plt.xlabel('Time [ps]'); plt.ylabel('Laser power [W]')
plt.show()

# %%
laserHeater = {
    "PowerProfile" : Pvector,  # Use this for 'arbitrary' case
    "tvector" : tvector,            # Use this for 'arbitrary' case
    "case" : 'arbitrary'
}

trackBeam(
    tao, 
    trackEnd = "LH10END", 
    laserHeater = laserHeater,
    **importedDefaultSettings
)

P = getBeamAtElement(tao, "LH10END")

display(plotMod(P, 'delta_t', 'energy', bins=300) )
plt.clf()
